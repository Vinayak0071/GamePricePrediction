# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report,accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('steam_test.csv')

# %%
pd.pandas.set_option('display.max_columns',None)
pd.pandas.set_option('display.max_rows',None)

# %%
categor_feat=[feat for feat in df.columns if df[feat].dtypes=='O']

# %%
df.drop

# %%
df.head()
# Out:
#      appid                           name release_date  english  \
# 0   514520                  Sparky's Hunt   2016-08-18        1
# 1  1012710                        Endzeit   2019-04-03        1
# 2   279260                Richard & Alice   2014-06-05        1
# 3   220090  The Journey Down: Chapter One   2013-01-09        1
# 4   788870       In The Long Run The Game   2018-07-02        1
#
#          developer        publisher          platforms  required_age  \
# 0      Luke Cripps     Fellowplayer            windows             0
# 1         RockyDev         RockyDev            windows             0
# 2         Owl Cave         Owl Cave            windows             0
# 3        SkyGoblin        SkyGoblin  windows;mac;linux             0
# 4  Zerstoren Games  Zerstoren Games            windows             0
#
#                                           categories  \
# 0                                      Single-player
# 1  Single-player;Multi-player;Co-op;Full controll...
# ...

# %%
df=df[['average_playtime','median_playtime','achievements','developer','publisher','positive_ratings','negative_ratings']]
df
# Out:
#       average_playtime  median_playtime  achievements  \
# 0                    0                0            14
# 1                   88               88             0
# 2                  332              332            21
# 3                  303              327             0
# 4                    0                0             0
# 5                    0                0             0
# 6                    0                0             0
# 7                    0                0            24
# 8                    0                0            26
# 9                    0                0            55
# 10                   0                0             0
# 11                   0                0             0
# 12                   0                0             7
# 13                   0                0             0
# 14                   0                0             0
# 15                   0                0            56
# ...

# %%
#feature_scale=[feat for feat in df.columns]
#from sklearn.preprocessing import MinMaxScaler
#sc=MinMaxScaler()
#df[feature_scale] = sc.fit_transform(df[feature_scale])

# %%
for i in categor_feat:
    mean_ord=df.groupby([i])['price'].mean().to_dict()
    df[i]=df[i].map(mean_ord)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-999af931c621> in <module>
#       1 for i in categor_feat:
# ----> 2     mean_ord=df.groupby([i])['price'].mean().to_dict()
#       3     df[i]=df[i].map(mean_ord)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...

# %%
df
# Out:
#       average_playtime  median_playtime  achievements  developer  publisher  \
# 0                 1519             1519            26          2          1
# 1                    3                1           882          1          1
# 2                    2                2            31          1          1
# 3                    2                1           882          1          1
# 4                 1519             1519           882          1          1
# ...                ...              ...           ...        ...        ...
# 2026                 3                1            38          1          1
# 2027              1519             1519            49          1          1
# 2028              1519             1519           882          1          4
# 2029              1519             1519           882          1          1
# 2030              1519             1519            28          1          1
#
#       positive_ratings  negative_ratings
# ...

# %%
df.to_csv('Updated_test.csv',index=False)
